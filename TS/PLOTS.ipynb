# %%
import matplotlib.pyplot as plt

# %%
train_loss = [0.13,0.127,0.127,0.125,0.0744,0.0579,0.0676,0.0254,0.123,0.00674]
val_loss = [0.119,0.119,0.115,0.114,0.115,0.119,0.119,0.125,0.127,0.139]
val_meteor = [0.93,0.933,0.934,0.934,0.935,0.935,0.936,0.936,0.936,0.936]
val_blue = [0.60,0.617,0.62,0.622,0.622,0.623,0.623,0.623,0.624,0.624]

# %%
plt.plot(train_loss,color='green',linestyle='dashed',marker='o',markerfacecolor='red')
plt.plot(val_loss,color='blue',linestyle='dashed',marker='o', markerfacecolor='red')

plt.grid()

plt.xticks(range(0, 10))
plt.xlabel('Epochs')
plt.ylabel('Loss ')
plt.title('Loss Plot : Train vs Validation')
plt.legend(['Train Loss','Validation Loss'],loc="best")
plt.show()
plt.savefig('Loss.png')

# %%
plt.plot(val_meteor,color='purple',linestyle='dashed',marker='o',markerfacecolor='red')

plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Scores ')
plt.title('Metric Plot : METEOR')
plt.legend(['METEOR'],loc="best")
plt.show()
plt.savefig('Metric.png')

# %%
plt.plot(val_blue,color='blue',linestyle='dashed',marker='o', markerfacecolor='red')

plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Scores ')
plt.title('Metric Plot : BLUE')
plt.legend(['BLUE'],loc="best")
plt.show()
plt.savefig('Metric.png')

# %%
NOTS_trloss = [4.640,3.800,4.390,4.670,4.820,3.850,3.880,4.190,4.230,4.000]
NOTS_valloss = [4.820,4.650,4.610,4.600,4.610,4.650,4.690,4.690,4.720,4.770]

# %%
plt.plot(NOTS_trloss,color='blue',linestyle='dashed',marker='o',markerfacecolor='red')
plt.plot(NOTS_valloss,color='green',linestyle='dashed',marker='o', markerfacecolor='red')

plt.grid()

plt.xticks(range(0, 10))
plt.xlabel('Epochs')
plt.ylabel('Loss ')
plt.title('Loss Plot : Train vs Validation')
plt.legend(['Train Loss','Validation Loss'],loc="best")
plt.show()
plt.savefig('Loss.png')

# %%
TS_trloss = [4.460,3.800,3.580,3.790,3.3370,3.430,3.460,3.410,3.410,3.630]
TS_valloss = [4.250,3.920,3.9,3.810,3.810,3.800,3.820,3.860,3.860,3.900,3.980]
TS_totalloss = [4.470,3.800,3.590,3.470,3.800,3.380,3.440,3.470,3.420,3.420,3.640]
TS_encloss = [0.0125,0.00655,0.00623,0.0062,0.0096,0.0111,0.00639,0.00666,0.00647,0.00663,0.00681]

# %%
plt.plot(TS_trloss,color='blue',linestyle='dashed',marker='o',markerfacecolor='red')
plt.plot(TS_valloss,color='green',linestyle='dashed',marker='o', markerfacecolor='red')
plt.plot(TS_totalloss,color='purple',linestyle='dashed',marker='o', markerfacecolor='red')

plt.grid()

plt.xticks(range(0, 10))
plt.xlabel('Epochs')
plt.ylabel('Loss ')
plt.title('Loss Plot : Train vs Validation')
plt.legend(['Train Loss','Validation Loss','Total Train Loss'],loc="best")
plt.show()
plt.savefig('Loss.png')

# %%
plt.plot(TS_encloss,color='purple',linestyle='dashed',marker='o', markerfacecolor='red')

plt.grid()

plt.xticks(range(0, 10))
plt.xlabel('Epochs')
plt.ylabel('Loss ')
plt.title('Loss Plot : Train vs Validation')
plt.legend(['Train Encoder Loss'],loc="best")
plt.show()
plt.savefig('Loss.png')
